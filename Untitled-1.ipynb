# %%
import numpy as np
import pandas as pd  
import matplotlib.pyplot as plt  
from sklearn.model_selection import train_test_split
from imblearn.under_sampling import RandomUnderSampler
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay, precision_recall_curve, average_precision_score

# %%
df = pd.read_csv(r"E:\belajar\archive_16\creditcard.csv")

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %% [markdown]
# terdapat 284807 baris dan 31 kolom

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.175161e-15  3.384974e-16 -1.379537e-15  2.094852e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.021879e-15  1.494498e-15 -5.620335e-16  1.149614e-16 -2.414189e-15
# ...

# %% [markdown]
# angka std besar besar menandakan data sangat menyebar dan jauh dari nilai rata rata

# %%
df.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# tidak ditemukan missing value

# %%
for column in df:
    print(df[column].unique())
# Out:
# [0.00000e+00 1.00000e+00 2.00000e+00 ... 1.72787e+05 1.72788e+05
#  1.72792e+05]
# [-1.35980713  1.19185711 -1.35835406 ...  1.91956501 -0.24044005
#  -0.53341252]
# [-0.07278117  0.26615071 -1.34016307 ... -0.30125385  0.53048251
#  -0.18973334]
# [ 2.53634674  0.16648011  1.77320934 ... -3.24963981  0.70251023
#   0.70333737]
# [ 1.37815522  0.44815408  0.37977959 ... -0.55782812  0.68979917
#  -0.50627124]
# [-0.33832077  0.06001765 -0.50319813 ...  2.63051512 -0.37796113
#  -0.01254568]
# [ 0.46238778 -0.08236081  1.80049938 ...  3.0312601   0.62370772
#  -0.64961669]
# [ 0.23959855 -0.07880298  0.79146096 ... -0.29682653 -0.68617999
#   1.57700625]
# [ 0.0986979   0.08510165  0.24767579 ...  0.70841718  0.67914546
#  -0.41465041]
# [ 0.36378697 -0.25542513 -1.51465432 ...  0.43245405  0.39208671
#   0.48617951]
# [ 0.09079417 -0.16697441  0.20764287 ... -0.48478176 -0.39912565
#  -0.91542665]
# [-0.55159953  1.61272666  0.62450146 ...  0.41161374 -1.93384882
#  -1.04045834]
# ...

# %% [markdown]
# tidak ditemukan keanehan dari nilai unik

# %%
df.duplicated().sum()
# Out:
# np.int64(1081)

# %% [markdown]
# ditemukan data duplikat sebanyak 1081

# %%
df = df.drop_duplicates()

# %%
#cek balance
class_counts = df['Class'].value_counts()
class_counts
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %% [markdown]
# terlihat ketidak seimbangan antara class 0 dan 1

# %%
x = df[['V1','V2','V3','V4','V5','V6','V7','V8','V9','V10','V11','V12','V13','V14','V15','V16','V17','V18','V19','V20','V21','V22','V23','V24','V25','V26','V27','V28','Time', 'Amount']]
y = df['Class']

# %%
x_train, x_test,y_train, y_test = train_test_split(x,y, test_size= 0.2, stratify=y, random_state = 167)

# %%
scaler = StandardScaler()
x_train_scaler = scaler.fit_transform(x_train)
x_test_scaler = scaler.transform(x_test)

# %%
rus = RandomUnderSampler(random_state=167)
x_train_rus, y_train_rus = rus.fit_resample(x_train_scaler, y_train)

# %%
svm = SVC()
svm.fit(x_train_rus,y_train_rus)
# Out:
# SVC()

# %%
y_pred_rus = svm.predict(x_test_scaler)
skor_rus = svm.decision_function(x_test_scaler)

# %%
svm = SVC()
svm.fit(x_train_scaler,y_train)
# Out:
# SVC()

# %%
y_pred = svm.predict(x_test_scaler)
skor_base = svm.decision_function(x_test_scaler)

# %%
print("accuracy tanpa balanced:",accuracy_score(y_test,y_pred))
print("accuracy dengan rus:",accuracy_score(y_test, y_pred_rus))
print("presisi baseline:", precision_score(y_test,y_pred))
print("presisi dengan rus:", precision_score(y_test, y_pred_rus))
print("recall baseline:", recall_score(y_test, y_pred))
print("recall dengan rus:", recall_score(y_test, y_pred_rus))
print("f1 score baseline:", f1_score(y_test, y_pred))
print("f1 score dengan rus:", f1_score(y_test, y_pred_rus))
# Out:
# accuracy tanpa balanced: 0.9994360836006062
# accuracy dengan rus: 0.982359990131463
# presisi baseline: 0.9846153846153847
# presisi dengan rus: 0.07424812030075188
# recall baseline: 0.6736842105263158
# recall dengan rus: 0.8315789473684211
# f1 score baseline: 0.8
# f1 score dengan rus: 0.1363244176013805

# %% [markdown]
# dilihat dari presisi dan recall dengan randomundersampler(rus) berbanding terbalik sama yang hanya baseline, kemungkinan baseline bisa mendapatkan setinggi itu karena data positif sudah sangat dominan pada awal, ketika di seimbangkan recall yang menggunakan rus menjadi sangat bagus

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 4))
ConfusionMatrixDisplay.from_predictions(y_test, y_pred, ax=ax[0])
ax[0].set_title('Baseline')
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_rus, ax=ax[1])
ax[1].set_title('Undersampling')
plt.show()

# %% [markdown]
# seperti yang terlihat sangat sedikit sekali baseline menebak true false, sedangkan undersampling menebak true false yang sangat banyak

# %%
# %% PR curve
for nama, skor in [('Baseline', skor_base), ('Undersampling', skor_rus)]:
    prec, rec, _ = precision_recall_curve(y_test, skor)
    ap = average_precision_score(y_test, skor)
    plt.plot(rec, prec, label=f'{nama} (PR-AUC = {ap:.3f})')

plt.axhline(y_test.mean(), color='gray', linestyle='--', label='Model acak')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend()
plt.show()

# %% [markdown]
# nilai pr auc baseline pun lebih tinggi

# %% [markdown]
# ## Analogi: bingkai foto dan lembar grafik
#
# Bayangkan Anda menempel beberapa grafik di satu papan.
#
# - **`fig` (figure)** = **papan atau kanvas besarnya**. Ini wadah untuk seluruh gambar.
# - **`ax` (axes)** = **satu kotak grafik di atas papan itu**. Sumbu x, sumbu y, garis, dan judul semuanya ada di dalam sebuah `ax`.
# - **subplot** = istilah untuk **satu grafik kecil di dalam papan yang berisi beberapa grafik**. Jadi satu `ax` sama dengan satu subplot.
#
# Sebuah `fig` bisa berisi satu `ax` atau banyak `ax`:
#
# ```
# fig (papan besar)
# ┌─────────────────────────────────┐
# │  ax[0]            ax[1]         │
# │ ┌──────────┐    ┌──────────┐    │
# │ │ grafik 1 │    │ grafik 2 │    │
# │ └──────────┘    └──────────┘    │
# └─────────────────────────────────┘
# ```
#
# Grafik yang Anda gambar tidak menempel langsung di papan, tapi di dalam kotak (`ax`).
#
# ## Membaca sintaks barisnya
#
# ```python
# fig, ax = plt.subplots(1, 2, figsize=(10, 4))
# ```
#
# ### `plt.subplots(...)`
# Fungsi ini artinya "siapkan papan dan kotak-kotak grafiknya". Perhatikan huruf **s** di akhir. Ini berbeda dengan `plt.subplot` (tanpa s), yang cara pakainya lebih kuno. Pakai yang berakhiran **s**.
#
# ### Tiga argumen di dalamnya
#
# | Argumen | Artinya | Nilai di contoh |
# |---|---|---|
# | Argumen 1 | jumlah **baris** kotak | `1` |
# | Argumen 2 | jumlah **kolom** kotak | `2` |
# | `figsize=(10, 4)` | ukuran papan (lebar, tinggi) dalam inci | lebar 10, tinggi 4 |
#
# Jadi `(1, 2)` artinya 1 baris dan 2 kolom, atau dua kotak berdampingan ke kanan. Kalau `(2, 1)`, dua kotak bertumpuk ke bawah. Kalau `(2, 2)`, ada empat kotak.
#
# ### `fig, ax = ...`
# Fungsi `plt.subplots` mengembalikan **dua benda sekaligus**: papan dan kotak-kotaknya. Python membolehkan kita menampung dua nilai itu ke dua nama variabel:
#
# - `fig` menampung papannya.
# - `ax` menampung kotak-kotaknya.
#
# Anda bisa memberi nama lain (misalnya `papan, kotak = plt.subplots(...)`), tapi `fig, ax` adalah kebiasaan yang dipakai semua orang, jadi ikuti saja.
#
# ## Isi `ax` tergantung jumlah kotak
#
# | Yang dipanggil | Isi `ax` | Cara mengaksesnya |
# |---|---|---|
# | `plt.subplots()` atau `(1, 1)` | **satu** kotak | langsung `ax` |
# | `plt.subplots(1, 2)` | daftar 2 kotak | `ax[0]` dan `ax[1]` |
# | `plt.subplots(2, 2)` | tabel 2x2 kotak | `ax[0, 0]`, `ax[0, 1]`, `ax[1, 0]`, `ax[1, 1]` |
#
# Penomoran dimulai dari **0**, jadi `ax[0]` adalah kotak **pertama** (kiri) dan `ax[1]` adalah kotak **kedua** (kanan). Pada 2x2, `ax[baris, kolom]`, dan `ax[0, 1]` berarti baris pertama, kolom kedua.
#
# ## Cara menggambar di sebuah kotak
#
# Setelah punya `ax`, Anda menggambar dengan memanggil method milik kotak itu:
#
# ```python
# ax[0].plot(x, y)              # gambar garis di kotak kiri
# ax[0].set_title('Judul kiri') # judul kotak kiri
# ax[0].set_xlabel('Sumbu x')   # label sumbu x kotak kiri
# ax[0].set_ylabel('Sumbu y')   # label sumbu y kotak kiri
# ```
#
# Perhatikan bahwa kalau memakai `ax`, namanya berubah sedikit:
#
# | Gaya `plt` (satu grafik) | Gaya `ax` (banyak grafik) |
# |---|---|
# | `plt.title(...)` | `ax.set_title(...)` |
# | `plt.xlabel(...)` | `ax.set_xlabel(...)` |
# | `plt.ylabel(...)` | `ax.set_ylabel(...)` |
# | `plt.plot(...)` | `ax.plot(...)` |
# | `plt.legend()` | `ax.legend()` |
# | `plt.axhline(...)` | `ax.axhline(...)` |
#
# Kenapa ada dua gaya? Saat memanggil `plt.plot(...)` tanpa membuat `fig` dan `ax`, matplotlib diam-diam membuatkan satu papan dengan satu kotak untuk Anda. Itu sebabnya kode PR curve tadi bisa jalan tanpa `fig, ax`. Tapi kalau ingin **banyak grafik berdampingan**, Anda harus menentukan sendiri mau menggambar di kotak yang mana, dan di situlah `ax` diperlukan.
#
# ## Contoh kecil yang bisa langsung dicoba
#
# Tidak perlu dataset. Jalankan ini:
#
# ```python
# import matplotlib.pyplot as plt
#
# fig, ax = plt.subplots(1, 2, figsize=(10, 4))
#
# ax[0].plot([1, 2, 3], [1, 4, 9])
# ax[0].set_title('Kotak kiri')
#
# ax[1].plot([1, 2, 3], [3, 2, 1])
# ax[1].set_title('Kotak kanan')
#
# plt.show()
# ```
#
# Hasilnya dua grafik berdampingan dengan judul berbeda. Coba ubah `(1, 2)` menjadi `(2, 1)` dan lihat apa yang berubah.
#
# ## Kaitannya dengan kode confusion matrix
#
# ```python
# fig, ax = plt.subplots(1, 2, figsize=(10, 4))
# ConfusionMatrixDisplay.from_predictions(y_test, pred_base, ax=ax[0])
# ax[0].set_title('Baseline')
# ConfusionMatrixDisplay.from_predictions(y_test, pred_rus, ax=ax[1])
# ax[1].set_title('Undersampling')
# plt.show()
# ```
#
# Baris demi baris:
#
# 1. Siapkan papan dengan dua kotak berdampingan.
# 2. Gambar confusion matrix baseline. Argumen `ax=ax[0]` berarti "gambarnya taruh di kotak kiri". Tanpa argumen ini, ia akan menggambar di papan baru.
# 3. Beri judul "Baseline" pada kotak kiri.
# 4. Gambar confusion matrix undersampling di kotak kanan (`ax[1]`).
# 5. Beri judul "Undersampling" pada kotak kanan.
# 6. Tampilkan seluruh papan.
#
# ## Dua tambahan yang sering berguna
#
# - **`plt.tight_layout()`** (sebelum `plt.show()`) merapikan jarak antar kotak supaya judul dan label tidak saling menimpa.
# - **`fig.suptitle('Judul besar')`** memberi judul untuk seluruh papan, bukan satu kotak.
#
# ## Ringkasan satu kalimat
#
# `fig` adalah papan besarnya, `ax` adalah kotak grafik di atas papan, dan `subplots(baris, kolom)` menyiapkan keduanya. Untuk menggambar di kotak tertentu, panggil `ax[nomor]` lalu method-nya (`plot`, `set_title`, dan seterusnya).
#
# Coba jalankan contoh kecil tadi dulu. Kalau sudah, ubah menjadi `plt.subplots(2, 2)` dan isi keempat kotaknya (ingat aksesnya `ax[0, 0]` dan seterusnya). Kalau ada bagian yang masih membingungkan, tunjukkan bagian yang mana.

# %%
import pickle

pickle.dump(svm, open("model.pkl", "wb"))
pickle.dump(scaler, open("scaler.pkl", "wb"))
